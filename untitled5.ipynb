# %% [markdown]
# <a href="https://colab.research.google.com/github/09690106162/Advanced-predictive-analytics/blob/main/untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/09690106162/Advanced-predictive-analytics/main/similarweb.csv")

# %%
import missingno as msno
# Visualize missing values as a matrix
msno.matrix(df,figsize=(12,6))
# Out:
# <Axes: >

# %%
df
# Out:
#            name             site  global_rank  country_rank  category_rank  \
# 0        Adidas       adidas.com         1464           371             11
# 1         ASICS        asics.com         3505          1892             44
# 2      Columbia     columbia.com         9122          1918             93
# 3          Fila         fila.com        65229         16405            558
# 4       K-Swiss       kswiss.com       168994         32037           1020
# 5   New Balance   newbalance.com         5241          1165             62
# 6          Nike         nike.com          231           126              4
# 7          Puma         puma.com         1697          1851             92
# 8      Skechers     skechers.com         3246           650             26
# 9  Under Armour  underarmour.com         4976          1132             58
#
#   total_visits  bounce_rate  pages_per_visit avg_visit_duration  \
# 0        31.5M        49.84             4.85           00:03:01
# ...

# %%
import numpy as np

# Assuming 'data' is a numerical column with outliers
mean = np.mean(df)
std_dev = np.std(df)

# Define a threshold (e.g., 3 standard deviations) for outliers
threshold = 3

outliers = df[(df - mean) / std_dev > threshold]

# Remove outliers (optional)
df = df[~df['name'].isin(outliers)]
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# ...

# %%
# Combining two numerical features to create a new feature
df['name'] = df['global_rank'] + df['country_rank']

# %%
# Assuming 'category' is a categorical column
df = pd.get_dummies(df, columns=['country_rank'])

# %%
df
# Out:
#      name             site  global_rank  category_rank total_visits  \
# 0    1835       adidas.com         1464             11        31.5M
# 1    5397        asics.com         3505             44          14M
# 2   11040     columbia.com         9122             93         5.9M
# 3   81634         fila.com        65229            558         775K
# 4  201031       kswiss.com       168994           1020       267.1K
# 5    6406   newbalance.com         5241             62        10.7M
# 6     357         nike.com          231              4       150.9M
# 7    3548         puma.com         1697             92        27.4M
# 8    3896     skechers.com         3246             26        15.3M
# 9    6108  underarmour.com         4976             58        11.8M
#
#    bounce_rate  pages_per_visit avg_visit_duration  country1_name  \
# 0        49.84             4.85           00:03:01  United States
# 1        44.87             5.61           00:03:34  United States
# ...

# %%
# Create a logistic regression model
model = LogisticRegression(max_iter=100)  # You can choose other classifiers too

# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model's accuracy
accuracy = np.mean(predictions == y_test)
print("Model accuracy:", accuracy)
# Out:
# Model accuracy: 1.0

# %%
# Make predictions on the test set
predictions = model.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, predictions)
print("Model accuracy:", accuracy)

# Generate a classification report with precision, recall, and F1-score
report = classification_report(y_test, predictions, target_names=iris.target_names)
print("Classification Report:\n", report)

# Create a confusion matrix to visualize true positives, true negatives, false positives, and false negatives
confusion = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", confusion)
# Out:
# Model accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
